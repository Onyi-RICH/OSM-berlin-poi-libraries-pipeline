# %% [markdown]
# # Extract Berlin Libraries from OpenStreetMap (Overpass API)
#
# This notebook extracts all libraries in Berlin from OpenStreetMap using **OSMnx**.
#
# - Reasearch, discover, collecte, and evaluating datasets
# - Filter tag: `amenity=library`
# - Output: Raw GeoDataFrame with OSM attributes (in both .csv and .geojson format)
# - CRS: EPSG:4326

# %%
# imports

import osmnx as ox                  # fetch data from OpenStreetMap
import geopandas as gpd             # handle geospatial (map) data

# %%
# Function Definition
def extract_osm_libraries(place: str = "Berlin, Germany") -> gpd.GeoDataFrame: # Define the place for libraries
    """
    Fetch libraries from OSM for a given place.
    """
    tags = {"amenity": "library"}   # Define the tag for libraries
    gdf = ox.features_from_place(place, tags) # Fetch the data as a GeoDataFrame
    gdf = gdf.to_crs(epsg=4326)   # Convert to WGS84 coordinate system/CRS (that is EPSG:4326)
    gdf = gdf.reset_index()  # Reset index to get the OSM IDs as a column for easier handling
    return gdf

# %%
# Execute Extraction
libraries_gdf = extract_osm_libraries()
libraries_gdf.head()
# Out:
#   element         id                   geometry addr:city addr:country  \
# 0    node   29071031  POINT (13.34751 52.53124)    Berlin           DE
# 1    node   60848456  POINT (13.47084 52.53078)    Berlin           DE
# 2    node  203557001  POINT (13.53872 52.52816)    Berlin           DE
# 3    node  256922190   POINT (13.28719 52.5375)    Berlin           DE
# 4    node  257708789  POINT (13.20139 52.53613)    Berlin           DE
#
#   addr:housenumber addr:postcode          addr:street          addr:suburb  \
# 0               33         10559   Perleberger Straße               Moabit
# 1               14         10369  Anton-Saefkow-Platz                  NaN
# 2                4         12681  Helene-Weigel-Platz              Marzahn
# 3               18         13627             Halemweg  Charlottenburg-Nord
# 4               13         13597   Carl-Schurz-Straße              Spandau
#
#    amenity  ... name:es name:he name:ko name:no name:pl name:tr name:zh  \
# 0  library  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1  library  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2  library  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3  library  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4  library  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#   wheelchair:url year_of_construction roof:material
# 0            NaN                  NaN           NaN
# 1            NaN                  NaN           NaN
# 2            NaN                  NaN           NaN
# 3            NaN                  NaN           NaN
# 4            NaN                  NaN           NaN
#
# [5 rows x 153 columns]

# %%
libraries_gdf.describe(include='all').T
# Out:
#                       count unique  \
# element                 151      3
# id                    151.0    NaN
# geometry                151    151
# addr:city               122      1
# addr:country            102      1
# ...                     ...    ...
# name:tr                   1      1
# name:zh                   1      1
# wheelchair:url            1      1
# year_of_construction      2      2
# roof:material             1      1
#
#                                                                     top freq  \
# element                                                            node  110
# id                                                                  NaN  NaN
# geometry                                  POINT (13.3475136 52.5312448)    1
# addr:city                                                        Berlin  122
# addr:country                                                         DE  102
# ...                                                                 ...  ...
# name:tr                                       Berlin Eyalet Kütüphanesi    1
# name:zh                                                         柏林国立图书馆    1
# wheelchair:url        https://staatsbibliothek-berlin.de/vor-ort/men...    1
# year_of_construction                                         1903..1914    1
# roof:material                                                 tar_paper    1
#
#                                    mean                std       min  \
# element                             NaN                NaN       NaN
# id                    3112252880.576159  3865085392.572454  180594.0
# geometry                            NaN                NaN       NaN
# addr:city                           NaN                NaN       NaN
# addr:country                        NaN                NaN       NaN
# ...                                 ...                ...       ...
# name:tr                             NaN                NaN       NaN
# name:zh                             NaN                NaN       NaN
# wheelchair:url                      NaN                NaN       NaN
# year_of_construction                NaN                NaN       NaN
# roof:material                       NaN                NaN       NaN
#
#                               25%           50%           75%            max
# element                       NaN           NaN           NaN            NaN
# id                    260693927.5  1356847676.0  5154027551.5  13366816284.0
# geometry                      NaN           NaN           NaN            NaN
# addr:city                     NaN           NaN           NaN            NaN
# addr:country                  NaN           NaN           NaN            NaN
# ...                           ...           ...           ...            ...
# name:tr                       NaN           NaN           NaN            NaN
# name:zh                       NaN           NaN           NaN            NaN
# wheelchair:url                NaN           NaN           NaN            NaN
# year_of_construction          NaN           NaN           NaN            NaN
# roof:material                 NaN           NaN           NaN            NaN
#
# [153 rows x 11 columns]

# %%
# List the columns names of the GeoData

libraries_gdf.columns.to_list()
# Out:
# ['element',
#  'id',
#  'geometry',
#  'addr:city',
#  'addr:country',
#  'addr:housenumber',
#  'addr:postcode',
#  'addr:street',
#  'addr:suburb',
#  'amenity',
#  'check_date',
#  'check_date:opening_hours',
#  'description',
#  'name',
#  'opening_hours',
#  'phone',
#  'ref:isil',
#  'toilets:wheelchair',
#  'website',
#  'wheelchair',
#  'wheelchair:description',
#  'wikidata',
#  'wikimedia_commons',
#  'wikipedia',
#  'contact:phone',
#  'internet_access',
#  'internet_access:fee',
#  'internet_access:operator',
#  'contact:email',
#  'contact:website',
#  'garden:type',
#  'note',
#  'operator',
#  'wheelchair:description:de',
#  'email',
#  'short_name',
#  'name:en',
#  'operator:type',
#  'operator:wikidata',
#  'ref',
#  'air_conditioning',
#  'access',
#  'changing_table',
#  'kids_area:indoor',
#  'level',
#  'source',
#  'toilets',
#  'toilets:access',
#  'alt_name',
#  'contact:fax',
#  'outdoor_seating',
#  'fax',
#  'room:group_study',
#  'room:study_cabin',
#  'service:copy',
#  'service:scanner',
#  'addr:housename',
#  'addr:place',
#  'layer',
#  'name:etymology:wikidata',
#  'name:de',
#  'operator:wikipedia',
#  'official_name',
#  'addr:floor',
#  'internet_access:ssid',
#  'fixme',
#  'old_name',
#  'books:language:de',
#  'books:language:en',
#  'books:language:es',
#  'books:language:fr',
#  'books:language:ru',
#  'dog',
#  'indoor',
#  'language:de',
#  'language:en',
#  'language:others',
#  'name:it',
#  'smoking',
#  'wheelchair:description:en',
#  'wheelchair:description:eo',
#  'facebook',
#  'fee:icom_member',
#  'loc_name',
#  'min_age',
#  'name:fr',
#  'image',
#  'logo',
#  'ref:vatin',
#  'entrance',
#  'books',
#  'survey:date',
#  'ref:bik',
#  'ref:dbs',
#  'start_date',
#  'contact:facebook',
#  'contact:instagram',
#  'description:de',
#  'building',
#  'roof:shape',
#  'brand',
#  'building:colour',
#  'building:levels',
#  'building:material',
#  'heritage',
#  'heritage:operator',
#  'lda:criteria',
#  'network',
#  'network:short',
#  'network:wikidata',
#  'network:wikipedia',
#  'ref:lda',
#  'roof:levels',
#  'roof:colour',
#  'construction',
#  'postal_code',
#  'contact:twitter',
#  'short_name:en',
#  'name:ja',
#  'heritage:website',
#  'architect',
#  'name:ru',
#  'polling_station',
#  'building:part',
#  'blind:description:de',
#  'alt_name_1',
#  'baby_feeding',
#  'building:levels:underground',
#  'payment:cash',
#  'payment:credit_cards',
#  'payment:debit_cards',
#  'payment:girocard',
#  'payment:mastercard',
#  'payment:visa',
#  'room',
#  'contact:mastodon',
#  'mapillary',
#  'research_institution',
#  'type',
#  'architect:wikidata',
#  'branch',
#  'building:architecture',
#  'fee',
#  'name:es',
#  'name:he',
#  'name:ko',
#  'name:no',
#  'name:pl',
#  'name:tr',
#  'name:zh',
#  'wheelchair:url',
#  'year_of_construction',
#  'roof:material']

# %%
# Save Output as GeoJSON (with geometry)
output_path = "../sources/osm_libraries.geojson"   #  (includes geometry)
libraries_gdf.to_file(output_path, driver="GeoJSON")

# Save Output as CSV (tabular only, no geometry)
csv_output_path = "../sources/osm_libraries.csv"
libraries_gdf.to_csv(csv_output_path, index=False)

print(f"Extracted {len(libraries_gdf)} libraries")
# Out:
# Extracted 151 libraries
